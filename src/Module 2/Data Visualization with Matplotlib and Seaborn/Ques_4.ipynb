# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = {'Product': ['A', 'B', 'C', 'D'], 'Sales': [250, 150, 300, 450]}
df = pd.DataFrame(data)
sns.barplot(x='Product', y='Sales', data=df)
plt.title('Sales Comparison by Product')
plt.show()
